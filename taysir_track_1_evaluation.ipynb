# %%
import os, sys
import shutil
import subprocess

result_dir = "taysir_results_track_1"
if not os.path.isdir(result_dir):
    os.mkdir(result_dir)

# config
nn_script_path = "source/active_learning/system_under_learning/python/nn_connector_taysir_track_1.py"
transformer_script_path = "source/active_learning/system_under_learning/python/nn_connector_taysir_track_1_transformer.py"
ini_path = "ini/l_sharp.ini"
pred_ini_path = "ini/predict-count-driven.ini"

# dataset and models
path_to_models = "data/active_learning/test_nn_queries/taysir_competition/track1/models"
path_to_test_sets = "data/active_learning/test_nn_queries/taysir_competition/track1/test_sets"
path_to_train_sets = "data/active_learning/test_nn_queries/taysir_competition/track1/datasets"

json_ending = ".ff.final.json"
dot_ending = ".ff.final.dot"
result_ending = ".ff.final.json.result"

def get_start_and_end_symbol(i, path_to_train_sets):
    train_set_path = os.path.join(path_to_train_sets, "1.{}.taysir.valid.words".format(i))
    with open(train_set_path, "rt") as f:
        _ = f.readline()
        line = f.readline()
        line = line.strip().split()
        start_symbol = line[1]
        end_symbol = line[-1]
    return start_symbol, end_symbol

# %% [markdown]
# ## Train the models

# %%
for i in range(2, 8):
    if i==1:
        continue
        
    tmp_script_path = transformer_script_path if i==7 else nn_script_path
    
    model_name = "1.{}.taysir.model".format(i)
    model_path = os.path.join(path_to_models, model_name)
    
    start_symbol, end_symbol = get_start_and_end_symbol(i, path_to_train_sets)
    
    print("Starting training model nr. {}. Start-symbol={}, end-symbol={}".format(i, start_symbol, end_symbol))
    command = ["./flexfringe", "--ini={}".format(ini_path), "--start_symbol={}".format(start_symbol), \
               "--end_symbol={}".format(end_symbol), "--aptafile={}".format(model_path), tmp_script_path]
    p = subprocess.run(command, stdout=subprocess.PIPE,
                                stderr=subprocess.PIPE, universal_newlines=True)
    for outstr in p.stdout:
        sys.stdout.write(outstr)
    for outstr in p.stderr:
        sys.stderr.write(outstr)
    print("Finished training model nr. {}. Starting prediction.".format(i))
    
    test_set_name = "1.{}.taysir.test.combined".format(i)
    test_set_path = os.path.join(path_to_test_sets, test_set_name)
    command = ["./flexfringe", "--ini={}".format(pred_ini_path), \
               "--aptafile={}{}".format(tmp_script_path, json_ending), test_set_path]
    p = subprocess.run(command, stdout=subprocess.PIPE,
                                stderr=subprocess.PIPE, universal_newlines=True)
    for outstr in p.stderr:
        sys.stderr.write(outstr)
    print("Finished prediction. Move the files to the folder now.")
    
    shutil.move(tmp_script_path + json_ending, os.path.join(result_dir, "taysir_model_{}.json".format(i)))
    shutil.move(tmp_script_path + dot_ending, os.path.join(result_dir, "taysir_model_{}.dot".format(i)))
    shutil.move(tmp_script_path + result_ending, os.path.join(result_dir, "taysir_model_{}.result".format(i)))
    
    #command = ["dot", "-Tpdf", os.path.join(result_dir, "taysir_model_{}.dot".format(i)), ">>", \
    #           os.path.join(result_dir, "taysir_model_{}.pdf".format(i))]
    #p = subprocess.run(command, stdout=subprocess.PIPE,
    #                            stderr=subprocess.PIPE, universal_newlines=True)
    #for outstr in p.stderr:
    #    sys.stderr.write(outstr)
    print("Done with model nr. {}".format(i))
# Out:
# Starting training model nr. 2. Start-symbol=16, end-symbol=17
# Run in active learning mode.
# Loading module: nn_connector_taysir_track_1
# Loading the Neural network model in python module.
# Loading alphabet in python module.
# Setting internal flexfringe alphabet, inferred from the network's training alphabet
# Python module source/active_learning/system_under_learning/python/nn_connector_taysir_track_1.py loaded and initialized successfully.
# Using heuristic count_driven
# Alphabet: seq: 0 1 10 11 12 13 14 15 2 3 4 5 6 7 8 9
# We do an extend
# [0/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 27 found: 15 7 2 2 11 5 2 2 8 7 11 14 14 13 8 4 1 9 15 9 8 4 2 8 6 12 1
# Counterexample because tree not parsable
# Counterexample of length 26 found: 7 15 7 10 10 4 8 2 11 11 4 9 1 4 14 13 0 8 5 10 5 12 7 3 7 3
# [500/500000] samples suggested.
# [1000/500000] samples suggested.
# [1500/500000] samples suggested.
# [2000/500000] samples suggested.
# [2500/500000] samples suggested.
# [3000/500000] samples suggested.
# [3500/500000] samples suggested.
# [4000/500000] samples suggested.
# [4500/500000] samples suggested.
# [5000/500000] samples suggested.
# [5500/500000] samples suggested.
# [6000/500000] samples suggested.
# Predictions of the following counterexample: The true value: 0, predicted: 1
# Counterexample of length 26 found: 13 13 13 12 2 0 9 1 1 10 7 2 4 4 15 8 13 6 3 2 8 6 5 7 11 10
# Counterexample because tree not parsable
# Counterexample of length 30 found: 15 0 11 2 8 13 6 14 14 4 6 10 15 15 12 9 0 12 8 8 15 4 8 5 3 7 10 13 4 4
# Counterexample because tree not parsable
# Counterexample of length 29 found: 13 13 0 14 3 11 5 13 8 1 6 8 5 14 8 7 6 0 3 4 8 11 14 13 11 5 13 1 6
# Counterexample because tree not parsable
# Counterexample of length 26 found: 10 6 15 7 15 2 12 1 12 4 6 11 4 7 3 12 13 10 8 4 10 0 4 12 6 8
# Counterexample because tree not parsable
# Counterexample of length 28 found: 3 6 14 0 5 12 15 13 12 15 14 6 0 1 8 15 5 13 3 8 8 2 6 14 1 9 10 2
# Counterexample because tree not parsable
# Counterexample of length 28 found: 7 1 0 5 13 9 2 5 2 2 10 8 12 11 1 3 11 10 6 2 15 6 3 8 11 7 4 12
# Counterexample because tree not parsable
# Counterexample of length 28 found: 15 8 5 7 6 4 6 13 14 4 6 13 14 5 12 7 0 14 15 13 4 3 2 8 6 11 1 13
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 30 found: 4 7 11 6 10 3 11 8 4 13 13 15 15 8 15 0 6 6 9 8 7 0 1 2 6 9 5 1 4 6
# Counterexample because tree not parsable
# Counterexample of length 27 found: 15 8 15 8 13 5 12 8 1 13 4 9 8 3 4 9 9 4 8 15 0 10 5 0 7 11 9
# Counterexample because tree not parsable
# Counterexample of length 30 found: 13 9 5 3 8 14 5 7 14 0 8 13 4 12 1 13 0 3 1 11 13 12 3 11 3 13 10 0 2 7
# Counterexample because tree not parsable
# Counterexample of length 28 found: 6 3 1 9 4 13 0 5 0 14 1 13 6 13 14 12 11 9 7 0 7 4 15 6 9 15 1 3
# Counterexample because tree not parsable
# Counterexample of length 29 found: 2 0 3 4 15 1 15 12 5 10 7 4 11 9 15 4 7 7 4 14 15 3 14 12 1 12 5 6 3
# Counterexample because tree not parsable
# Counterexample of length 28 found: 4 8 11 4 7 8 8 8 3 12 9 7 14 9 5 0 13 6 9 14 13 4 7 8 14 7 5 1
# Counterexample because tree not parsable
# Counterexample of length 29 found: 14 2 10 4 2 3 8 9 7 0 8 0 3 13 1 12 4 1 11 4 10 15 7 0 11 7 14 3 6
# Counterexample because tree not parsable
# Counterexample of length 26 found: 10 14 10 14 1 0 0 3 5 14 2 5 3 14 6 9 12 11 9 7 6 4 2 13 5 14
# Counterexample because tree not parsable
# Counterexample of length 26 found: 7 3 11 11 15 3 8 0 11 7 15 0 2 8 3 11 2 0 4 7 12 13 0 6 1 3
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 7 0 15 11 6 10 5 9 12 1 1 0 15 0 4 5 1 3 7 2 9 1 5 6 13 9 11 3 4
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 15 3 10 6 13 1 11 12 6 2 4 3 3 7 0 10 6 12 7 5 13 8 15 11 10 10
# Counterexample because tree not parsable
# Counterexample of length 25 found: 8 11 2 7 15 3 2 13 13 14 12 15 1 0 8 1 0 1 1 2 4 8 6 3 5
# Counterexample because tree not parsable
# Counterexample of length 27 found: 8 11 13 13 4 15 15 9 13 11 4 10 6 11 8 0 15 0 5 3 6 8 7 15 6 14 5
# Counterexample because tree not parsable
# Counterexample of length 25 found: 15 13 15 15 13 4 3 15 1 2 0 13 9 9 3 7 4 10 13 0 0 5 5 5 9
# Counterexample because tree not parsable
# Counterexample of length 30 found: 15 9 6 11 9 7 13 10 4 9 7 3 15 0 12 4 6 11 13 13 8 1 12 11 0 0 9 5 0 5
# Counterexample because tree not parsable
# Counterexample of length 29 found: 8 13 15 6 1 13 2 5 12 0 4 2 11 5 2 4 4 5 1 3 15 7 11 8 14 1 1 6 0
# Counterexample because tree not parsable
# Counterexample of length 30 found: 0 2 7 3 14 5 10 2 4 14 5 0 3 7 3 3 10 2 13 4 11 13 15 9 7 13 5 2 8 9
# Counterexample because tree not parsable
# Counterexample of length 30 found: 11 5 4 6 1 13 2 14 9 15 9 13 0 11 3 13 7 8 15 11 4 15 14 4 6 8 3 10 11 3
# Counterexample because tree not parsable
# Counterexample of length 28 found: 10 0 9 4 0 12 6 15 13 8 5 14 7 0 7 2 0 10 13 12 10 11 0 13 13 14 14 12
# Counterexample because tree not parsable
# Counterexample of length 28 found: 1 11 11 6 10 10 4 13 10 11 0 1 0 8 7 14 3 1 2 10 5 3 10 0 5 1 9 14
# Counterexample because tree not parsable
# Counterexample of length 26 found: 1 13 13 14 10 13 1 1 15 11 6 6 6 12 2 0 6 12 4 12 7 0 1 6 15 7
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 28 found: 14 15 13 15 14 12 3 13 10 4 2 12 15 5 14 15 0 14 3 4 1 8 8 13 13 3 15 15
# Counterexample because tree not parsable
# Counterexample of length 30 found: 1 9 0 4 12 15 5 1 15 1 4 8 8 13 13 1 9 13 10 3 5 14 11 11 14 6 6 5 15 11
# Counterexample because tree not parsable
# Counterexample of length 27 found: 14 1 8 0 2 13 8 13 14 5 7 11 12 13 4 0 13 10 0 8 0 6 1 7 1 11 11
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 9 10 11 8 2 14 14 9 1 7 14 1 6 0 9 5 1 8 12 13 13 3 7 2 1 2 0 0 11
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 30 found: 13 3 12 5 9 10 13 2 2 3 5 0 1 1 11 2 11 1 8 3 12 10 12 5 7 13 13 12 7 8
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 27 found: 9 11 7 0 3 3 14 3 1 4 3 15 13 5 10 15 10 8 12 5 12 14 0 3 1 13 13
# Counterexample because tree not parsable
# Counterexample of length 26 found: 2 4 4 4 0 13 7 4 5 4 7 13 1 14 13 6 0 4 10 1 11 15 13 3 7 5
# Counterexample because tree not parsable
# Counterexample of length 30 found: 1 7 9 12 14 1 7 12 6 11 12 4 9 10 8 12 2 0 7 8 4 9 13 5 11 0 12 9 15 13
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 28 found: 2 6 4 9 12 1 9 11 8 13 9 15 7 0 3 14 6 6 1 0 15 13 13 10 12 3 4 12
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 8 7 11 0 5 8 14 7 3 5 13 14 3 5 2 8 6 0 0 12 10 5 13 13 2 4 9 2 10
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 0 1 0 11 8 14 11 13 15 7 4 2 1 14 5 14 4 15 7 7 12 3 6 14 1 5
# Counterexample because tree not parsable
# Counterexample of length 30 found: 0 9 6 4 6 1 7 7 3 1 15 0 13 5 13 6 8 14 0 10 15 11 8 7 11 3 13 14 1 14
# Counterexample because tree not parsable
# Counterexample of length 30 found: 14 0 15 6 9 13 13 15 6 6 6 3 14 11 0 8 14 6 0 0 6 5 7 5 4 14 0 8 4 10
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 30 found: 1 12 8 11 3 2 7 14 10 10 6 3 7 9 3 14 10 15 4 4 13 0 4 4 2 0 13 13 2 11
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 2 1 6 5 7 9 11 10 2 12 10 15 8 4 1 12 11 13 5 2 10 13 2 11 2 14
# Counterexample because tree not parsable
# Counterexample of length 27 found: 7 15 14 15 11 5 10 4 14 8 10 6 10 11 8 13 15 12 6 3 6 10 11 8 10 2 8
# Counterexample because tree not parsable
# Counterexample of length 30 found: 1 6 11 12 2 12 12 12 5 9 14 3 6 11 9 2 7 13 6 7 2 5 1 11 1 11 14 14 1 4
# Counterexample because tree not parsable
# Counterexample of length 27 found: 12 14 11 11 6 12 13 10 1 3 12 9 12 11 8 5 1 4 9 10 0 1 7 10 13 4 10
# Counterexample because tree not parsable
# Counterexample of length 29 found: 5 11 9 5 9 14 15 10 13 14 5 2 7 1 13 0 5 5 13 4 6 4 3 15 7 6 9 4 15
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 30 found: 5 9 5 5 8 8 5 12 6 6 2 11 3 4 3 0 3 4 3 5 10 5 10 10 3 3 13 13 12 11
# Counterexample because tree not parsable
# Counterexample of length 26 found: 10 11 8 2 7 8 6 14 11 10 4 0 1 0 2 12 10 5 9 4 2 5 8 15 7 1
# Counterexample because tree not parsable
# Counterexample of length 26 found: 15 11 6 9 4 0 1 8 13 8 9 0 3 0 14 14 8 11 1 13 9 15 13 6 4 0
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 11 6 3 9 1 11 11 8 0 11 14 1 4 12 4 13 0 15 8 1 6 15 1 3
# Counterexample because tree not parsable
# Counterexample of length 25 found: 5 3 8 4 9 6 3 11 0 5 2 10 13 1 2 12 2 5 13 15 3 1 13 0 7
# Counterexample because tree not parsable
# Counterexample of length 29 found: 6 0 0 5 0 6 4 5 11 4 13 13 0 11 5 11 4 6 4 14 7 1 13 9 8 5 1 3 10
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 26 found: 3 8 2 13 13 9 8 10 10 5 10 9 7 12 0 7 1 1 5 13 10 2 10 12 6 10
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 27 found: 8 8 5 15 8 8 11 2 12 4 8 8 14 7 12 7 13 13 5 4 2 3 0 9 3 12 1
# Counterexample because tree not parsable
# Counterexample of length 30 found: 7 7 8 11 1 2 3 10 2 2 10 13 13 14 10 15 15 0 2 5 8 1 5 0 12 5 4 1 10 4
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 5 8 5 12 0 7 11 3 6 2 14 15 6 4 9 7 4 8 12 13 13 5 6 0 0 0 5 12 3
# Counterexample because tree not parsable
# Counterexample of length 30 found: 12 14 2 6 3 10 2 5 13 13 14 7 7 5 6 0 13 11 13 3 12 14 2 14 12 13 8 8 2 14
# Counterexample because tree not parsable
# Counterexample of length 28 found: 4 15 6 2 10 9 13 5 14 13 1 8 6 15 1 9 9 1 1 7 11 6 2 10 7 4 10 14
# Counterexample because tree not parsable
# Counterexample of length 26 found: 15 7 13 2 11 11 13 1 9 10 0 1 13 13 7 15 1 4 10 0 12 2 14 2 7 12
# Counterexample because tree not parsable
# Counterexample of length 25 found: 8 5 9 1 7 7 9 4 13 10 5 9 2 5 15 6 13 9 7 5 15 15 4 11 0
# Counterexample because tree not parsable
# Counterexample of length 26 found: 3 11 10 9 2 11 13 5 6 5 6 15 6 15 8 13 9 15 2 14 1 6 2 6 13 6
# Counterexample because tree not parsable
# Counterexample of length 30 found: 0 3 10 7 0 11 15 13 14 15 6 10 1 5 12 11 3 14 6 5 15 11 3 3 8 10 2 11 7 13
# Counterexample because tree not parsable
# Counterexample of length 29 found: 2 5 0 2 2 2 6 2 15 13 3 7 8 10 4 13 9 6 3 1 3 3 5 14 6 10 8 1 15
# Counterexample because tree not parsable
# Counterexample of length 25 found: 5 12 6 8 13 14 15 9 15 14 10 9 3 4 6 0 7 10 0 7 4 6 7 14 1
# Counterexample because tree not parsable
# Counterexample of length 29 found: 14 12 2 4 6 12 9 2 9 4 10 14 1 2 9 12 4 14 13 3 13 2 8 14 9 7 9 4 0
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 6 11 11 13 13 15 12 9 4 4 15 12 0 4 6 11 8 5 11 9 12 7 5 3 5 3 15 2 5
# Counterexample because tree not parsable
# Counterexample of length 27 found: 5 12 6 1 8 11 8 11 9 7 12 4 9 14 7 6 8 5 7 15 8 13 1 13 0 8 0
# Counterexample because tree not parsable
# Counterexample of length 28 found: 6 1 2 3 15 4 8 10 15 10 8 0 14 14 1 14 11 8 12 8 7 12 0 14 4 0 8 8
# Counterexample because tree not parsable
# Counterexample of length 30 found: 5 8 6 4 1 8 5 8 1 1 5 13 1 5 14 9 6 4 1 11 8 3 13 13 9 12 8 2 8 4
# Counterexample because tree not parsable
# Counterexample of length 27 found: 5 9 14 13 15 5 13 1 15 8 9 11 13 0 3 13 2 1 3 11 13 7 1 12 1 2 1
# Counterexample because tree not parsable
# Counterexample of length 27 found: 3 9 11 10 9 11 8 14 8 0 4 13 5 0 1 7 15 0 1 4 3 13 2 2 12 1 2
# Counterexample because tree not parsable
# Counterexample of length 25 found: 6 1 7 9 7 13 13 11 6 13 14 2 0 11 12 11 4 6 1 1 2 5 10 13 10
# Counterexample because tree not parsable
# Counterexample of length 28 found: 8 9 1 3 8 8 11 11 5 9 9 8 12 13 13 1 6 4 13 5 9 11 7 8 2 12 14 4
# Counterexample because tree not parsable
# Counterexample of length 30 found: 5 11 13 10 9 8 12 10 14 5 15 14 12 11 15 7 15 1 13 5 4 11 8 5 10 10 7 12 12 5
# Counterexample because tree not parsable
# Counterexample of length 25 found: 12 14 6 3 0 13 13 15 5 8 5 7 4 6 5 3 4 3 14 5 6 7 8 10 2
# Counterexample because tree not parsable
# Counterexample of length 27 found: 6 4 1 11 13 15 11 7 9 10 1 9 5 0 9 7 13 4 7 7 3 4 13 7 15 15 8
# Counterexample because tree not parsable
# Counterexample of length 29 found: 1 9 3 8 6 9 0 15 7 15 7 5 7 2 10 13 3 14 8 1 8 8 7 11 8 11 10 2 8
# Counterexample because tree not parsable
# Counterexample of length 26 found: 9 11 13 3 6 12 1 7 10 0 13 13 14 0 1 15 15 3 1 2 0 13 0 1 8 5
# [6500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 29 found: 6 4 3 15 15 10 12 10 8 5 13 11 2 13 13 9 3 0 10 9 3 14 7 7 4 14 4 14 13
# Counterexample because tree not parsable
# Counterexample of length 27 found: 6 4 8 13 13 10 2 2 4 1 9 9 11 9 7 14 11 10 10 7 2 11 11 8 1 1 5
# Counterexample because tree not parsable
# Counterexample of length 27 found: 7 13 4 5 7 6 13 13 6 10 10 13 0 10 15 8 13 14 8 4 10 5 13 15 6 11 5
# Counterexample because tree not parsable
# Counterexample of length 28 found: 1 8 1 2 4 3 1 15 14 7 11 5 0 1 3 4 13 12 3 15 0 5 9 8 3 7 13 12
# Counterexample because tree not parsable
# Counterexample of length 29 found: 2 0 15 6 12 9 1 9 9 10 14 10 10 9 2 1 13 5 10 14 7 11 3 6 4 7 5 13 4
# Counterexample because tree not parsable
# Counterexample of length 26 found: 8 11 9 2 6 13 0 7 14 1 4 6 15 7 1 13 13 14 4 10 8 10 11 15 6 5
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 25 found: 6 10 9 13 11 11 6 7 0 15 1 14 11 1 15 7 1 6 12 4 13 13 3 7 13
# Counterexample because tree not parsable
# Counterexample of length 28 found: 4 4 4 10 3 2 4 4 15 6 0 3 13 13 14 9 4 15 2 4 11 0 4 12 3 9 8 3
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 30 found: 8 11 9 4 2 10 14 7 2 1 13 4 2 14 6 12 9 15 2 9 3 14 7 14 7 13 13 7 11 15
# Counterexample because tree not parsable
# Counterexample of length 26 found: 15 9 13 4 14 10 13 10 5 8 7 3 4 15 3 2 14 0 15 0 2 12 10 12 9 3
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 30 found: 3 9 11 8 1 13 13 12 8 4 11 1 6 6 3 7 10 11 10 9 0 6 3 13 12 1 4 3 10 4
# Counterexample because tree not parsable
# Counterexample of length 26 found: 1 5 2 9 11 6 8 3 2 3 2 10 2 7 0 1 8 11 8 4 11 3 7 9 14 14
# Counterexample because tree not parsable
# Counterexample of length 28 found: 15 7 15 0 0 11 13 6 1 14 1 10 12 13 11 11 11 3 10 11 0 10 14 1 8 0 15 13
# Counterexample because tree not parsable
# Counterexample of length 26 found: 0 2 0 13 2 8 3 5 7 2 5 4 0 2 2 10 2 12 9 8 4 3 14 3 8 9
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 27 found: 2 1 6 3 4 2 13 5 6 7 7 7 0 5 10 15 5 11 10 13 13 4 15 4 8 12 8
# Counterexample because tree not parsable
# Counterexample of length 29 found: 0 8 12 14 5 3 6 2 7 4 14 14 13 13 4 7 2 15 0 8 11 8 7 14 13 2 1 1 7
# Counterexample because tree not parsable
# Counterexample of length 28 found: 14 8 1 4 7 7 12 13 2 6 8 12 7 0 14 10 4 1 14 12 6 6 5 14 5 14 4 3
# Iteration 101
# Counterexample because tree not parsable
# Counterexample of length 30 found: 8 9 3 13 0 12 15 1 13 13 12 4 13 1 1 15 13 2 11 4 8 5 7 11 6 10 1 14 5 12
# Counterexample because tree not parsable
# Counterexample of length 29 found: 13 7 8 4 7 13 13 9 12 13 6 14 1 3 0 14 1 4 0 15 3 10 8 3 0 14 14 9 5
# Counterexample because tree not parsable
# Counterexample of length 25 found: 4 6 4 12 8 14 0 1 12 15 4 10 2 0 1 6 8 1 13 7 14 8 0 6 12
# Counterexample because tree not parsable
# Counterexample of length 27 found: 1 1 13 10 0 6 3 4 1 7 1 13 13 6 14 12 0 7 13 8 6 10 8 3 9 15 14
# Counterexample because tree not parsable
# Counterexample of length 25 found: 0 11 15 6 2 0 13 12 14 4 0 13 0 7 14 1 3 7 4 9 2 12 7 0 5
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 25 found: 2 4 4 14 11 6 7 5 13 13 9 11 4 9 0 6 7 8 11 8 5 7 6 2 7
# Counterexample because tree not parsable
# Counterexample of length 29 found: 1 1 3 3 15 5 9 13 7 6 6 7 11 11 3 11 10 10 0 12 0 12 0 2 13 8 15 11 3
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 28 found: 9 3 13 1 13 12 5 5 6 7 13 2 3 1 2 1 9 8 1 4 2 6 4 5 2 9 9 8
# Counterexample because tree not parsable
# Counterexample of length 30 found: 6 13 4 0 3 13 6 7 1 11 9 12 12 0 14 13 7 4 9 7 8 7 4 14 8 11 11 11 13 9
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 25 found: 8 6 8 3 1 11 5 14 13 0 13 5 3 5 6 14 6 13 6 1 9 12 9 6 12
# Counterexample because tree not parsable
# Counterexample of length 28 found: 4 2 7 8 6 5 8 8 4 5 0 15 11 10 2 13 5 5 1 8 1 1 2 9 1 1 14 9
# Counterexample because tree not parsable
# Counterexample of length 26 found: 14 8 0 11 14 12 1 14 5 6 13 13 6 10 10 13 3 2 8 14 3 12 6 12 6 5
# Counterexample because tree not parsable
# Counterexample of length 30 found: 8 8 12 7 3 10 7 15 6 8 14 2 4 10 1 0 11 4 10 13 1 4 9 6 8 8 15 9 11 5
# Counterexample because tree not parsable
# Counterexample of length 29 found: 13 1 12 14 15 7 14 2 2 5 8 9 7 12 15 1 10 1 0 10 11 1 8 6 5 3 9 2 1
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 12 6 4 1 2 10 15 13 0 3 13 15 6 12 7 7 2 0 6 8 0 12 0 5
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 10 4 4 15 15 12 1 6 15 10 11 0 14 5 7 14 9 4 0 9 15 13 9 12
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 14 13 14 14 15 1 2 9 5 14 15 5 13 1 13 14 7 15 7 10 9 14 9 14
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 8 8 9 0 13 7 9 7 4 13 1 3 15 2 12 15 7 1 3 3 8 9 7 2 5 11 10
# Counterexample because tree not parsable
# Counterexample of length 29 found: 10 0 8 4 7 13 12 8 9 2 12 1 5 5 13 12 12 1 7 15 2 5 4 12 5 0 4 4 9
# Counterexample because tree not parsable
# Counterexample of length 27 found: 14 11 11 3 13 12 0 10 6 12 9 3 6 3 1 15 5 10 11 3 11 5 15 12 11 6 0
# [7000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 26 found: 3 5 2 12 1 3 6 8 11 2 1 15 13 8 15 13 10 12 11 7 6 0 11 0 2 12
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 14 12 4 9 4 10 10 4 0 1 13 13 4 13 15 1 5 12 1 15 7 10 13 11 15 6 3 6 1
# Counterexample because tree not parsable
# Counterexample of length 30 found: 7 15 12 5 6 15 4 11 3 8 9 15 0 0 0 3 13 13 3 8 2 6 13 14 15 8 3 0 14 10
# Counterexample because tree not parsable
# Counterexample of length 27 found: 14 11 14 15 4 14 4 7 8 7 14 10 12 12 2 5 11 14 15 11 15 11 9 13 11 13 2
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 9 8 10 2 3 13 13 0 15 4 7 4 12 4 11 13 1 2 12 7 4 10 10 0 1 5 10 4 11
# Counterexample because tree not parsable
# Counterexample of length 29 found: 8 0 1 6 7 15 4 15 6 0 0 15 8 5 2 3 9 9 9 14 3 3 10 11 10 1 12 11 2
# Counterexample because tree not parsable
# Counterexample of length 26 found: 11 0 1 1 6 13 5 9 13 10 9 3 2 6 13 14 8 3 6 8 7 0 4 14 15 9
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 29 found: 7 11 5 13 9 0 3 15 0 11 6 9 1 13 13 7 2 7 3 12 13 7 11 3 10 1 0 6 2
# Counterexample because tree not parsable
# Counterexample of length 27 found: 3 10 3 7 3 9 13 15 9 5 14 1 13 13 8 14 5 0 6 1 11 2 11 12 8 6 0
# Counterexample because tree not parsable
# Counterexample of length 30 found: 6 15 10 6 5 8 6 1 3 5 8 2 1 4 4 13 9 15 5 4 14 6 15 0 14 11 1 10 4 10
# Counterexample because tree not parsable
# Counterexample of length 30 found: 0 12 8 13 13 8 12 5 15 6 4 4 7 0 4 10 9 8 11 2 5 3 10 4 3 11 7 14 4 10
# Counterexample because tree not parsable
# Counterexample of length 29 found: 13 6 7 6 7 9 6 15 3 15 14 4 2 9 10 14 2 1 3 1 7 2 6 8 11 12 9 4 5
# Predictions of the following counterexample: The true value: 1, predicted: 0
# Counterexample of length 30 found: 1 8 12 14 5 10 4 5 15 2 10 13 13 4 4 1 3 5 1 4 1 3 9 1 2 4 2 13 0 8
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 4 13 10 5 2 6 1 12 6 8 3 8 5 10 3 4 14 3 12 0 13 11 2 10 10 11 11
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 13 12 7 1 0 0 13 3 2 13 5 0 5 6 15 12 11 12 13 11 15 13 6 12 15 5
# [7500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 5 1 2 15 13 12 14 1 14 9 9 8 14 11 3 2 6 0 5 13 13 2 14 13
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 13 2 9 5 7 0 9 10 6 5 10 2 5 12 15 12 15 15 14 10 1 4 12 14 11 0
# [8000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 13 8 7 3 7 15 11 13 13 8 4 1 3 4 4 13 13 8 5 5 14 0 3 15 14 6
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 13 10 7 6 1 2 9 3 6 4 13 13 0 11 6 13 13 14 14 14 2 1 12 5 11 6 0
# Counterexample because tree not parsable
# Counterexample of length 29 found: 13 13 11 12 12 2 14 7 13 4 4 10 7 7 9 12 13 13 0 2 12 11 2 3 9 10 12 14 7
# [8500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 13 5 12 2 0 8 4 15 5 13 13 10 15 8 15 0 10 11 14 6 15 15 5 12
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 13 4 10 1 6 0 15 15 4 14 15 10 4 15 15 3 3 1 7 10 6 3 14 7
# [9000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 13 15 1 4 15 8 3 1 0 1 15 12 13 4 12 15 3 9 5 12 6 3 2 10 2 6
# [9500/500000] samples suggested.
# [10000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 26 found: 13 13 6 1 10 6 9 2 12 7 11 15 5 4 0 1 1 1 12 3 0 9 11 10 8 1
# [10500/500000] samples suggested.
# [11000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 29 found: 13 13 13 7 2 12 2 14 4 7 15 10 4 5 3 12 9 15 13 11 6 14 4 8 13 7 11 11 8
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 13 14 4 5 0 10 2 3 7 2 11 0 0 13 6 8 8 3 11 14 1 6 1 14 3 15 7
# [11500/500000] samples suggested.
# [12000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 29 found: 13 13 3 6 10 0 5 4 3 9 1 11 4 3 14 12 0 6 6 11 6 10 14 0 14 9 14 7 0
# [12500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 13 1 6 10 13 4 9 3 4 13 12 4 1 2 3 13 6 4 4 11 11 12 9 5
# [13000/500000] samples suggested.
# [13500/500000] samples suggested.
# [14000/500000] samples suggested.
# [14500/500000] samples suggested.
# [15000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 13 9 10 10 14 5 8 4 9 0 5 1 5 2 3 11 9 3 3 9 5 6 4 0 10 2
# [15500/500000] samples suggested.
# [16000/500000] samples suggested.
# [16500/500000] samples suggested.
# [17000/500000] samples suggested.
# [17500/500000] samples suggested.
# [18000/500000] samples suggested.
# [18500/500000] samples suggested.
# [19000/500000] samples suggested.
# [19500/500000] samples suggested.
# [20000/500000] samples suggested.
# [20500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 26 found: 13 13 7 11 8 10 9 10 7 11 13 4 8 0 13 0 13 14 7 8 3 7 4 2 11 9
# [21000/500000] samples suggested.
# [21500/500000] samples suggested.
# [22000/500000] samples suggested.
# [22500/500000] samples suggested.
# [23000/500000] samples suggested.
# [23500/500000] samples suggested.
# [24000/500000] samples suggested.
# [24500/500000] samples suggested.
# [25000/500000] samples suggested.
# [25500/500000] samples suggested.
# [26000/500000] samples suggested.
# [26500/500000] samples suggested.
# Predictions of the following counterexample: The true value: 0, predicted: 1
# Counterexample of length 25 found: 13 7 13 13 13 8 7 8 15 15 2 4 6 10 9 3 8 4 2 9 14 1 11 2 9
# [27000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 27 found: 13 7 5 7 9 15 0 1 8 4 6 14 4 9 12 2 15 4 5 10 5 11 14 2 15 15 10
# [27500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 7 4 11 3 7 4 1 3 13 5 7 12 11 3 13 12 0 1 5 0 4 7 1 5 1 0 4
# Counterexample because tree not parsable
# Counterexample of length 30 found: 13 7 6 1 12 10 7 0 3 15 5 5 6 9 1 4 2 1 4 12 15 8 1 8 14 10 8 2 12 12
# [28000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 7 12 14 7 3 7 8 14 12 2 11 2 7 12 4 2 10 10 10 11 8 0 5 1 0 14 2
# [28500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 26 found: 13 7 11 0 0 7 13 12 15 15 3 9 13 0 8 5 13 15 11 2 11 13 3 12 2 3
# [29000/500000] samples suggested.
# [29500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 30 found: 13 7 10 9 2 5 5 9 2 14 2 7 4 12 6 14 13 13 7 13 6 10 14 13 6 8 11 6 7 4
# [30000/500000] samples suggested.
# [30500/500000] samples suggested.
# [31000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 26 found: 13 7 9 1 0 14 6 0 10 9 0 12 0 12 8 4 1 10 4 10 5 2 7 3 5 13
# Counterexample because tree not parsable
# Counterexample of length 30 found: 13 7 2 6 1 4 9 12 4 13 6 13 0 5 14 10 9 11 1 7 13 1 2 8 9 2 6 11 12 1
# [31500/500000] samples suggested.
# [32000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 7 7 8 0 2 14 11 0 8 7 9 7 12 11 6 13 13 1 5 4 0 10 14 9 12 6 5
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 7 1 11 7 8 13 13 3 4 3 5 3 14 13 13 0 11 0 6 14 7 14 3 15 7 7 8
# [32500/500000] samples suggested.
# [33000/500000] samples suggested.
# [33500/500000] samples suggested.
# [34000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 7 0 11 13 6 3 13 4 6 13 6 5 2 4 15 12 12 3 3 11 12 5 2 10 12 8 9
# Counterexample because tree not parsable
# Counterexample of length 26 found: 13 7 3 8 15 15 1 10 12 1 0 2 9 0 4 4 2 1 8 7 8 9 13 7 15 8
# [34500/500000] samples suggested.
# [35000/500000] samples suggested.
# [35500/500000] samples suggested.
# [36000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 7 14 10 1 3 10 13 5 8 10 3 5 13 15 10 5 6 7 9 11 15 6 15 7 9 1 12
# Counterexample because tree not parsable
# Counterexample of length 26 found: 13 13 13 5 4 14 15 2 0 1 5 0 8 11 10 0 2 11 14 12 10 8 12 9 14 8
# [36500/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 25 found: 13 7 15 11 11 6 15 8 3 15 15 9 4 11 15 7 4 11 13 3 11 6 0 10 15
# [37000/500000] samples suggested.
# [37500/500000] samples suggested.
# [38000/500000] samples suggested.
# [38500/500000] samples suggested.
# [39000/500000] samples suggested.
# [39500/500000] samples suggested.
# [40000/500000] samples suggested.
# [40500/500000] samples suggested.
# [41000/500000] samples suggested.
# [41500/500000] samples suggested.
# [42000/500000] samples suggested.
# [42500/500000] samples suggested.
# [43000/500000] samples suggested.
# [43500/500000] samples suggested.
# [44000/500000] samples suggested.
# [44500/500000] samples suggested.
# [45000/500000] samples suggested.
# Counterexample because tree not parsable
# Counterexample of length 28 found: 13 13 13 3 1 11 13 10 2 15 10 4 12 11 8 5 3 12 1 13 8 9 6 5 5 11 6 1
# [45500/500000] samples suggested.
# [46000/500000] samples suggested.
# [46500/500000] samples suggested.
# [47000/500000] samples suggested.
# [47500/500000] samples suggested.
# [48000/500000] samples suggested.
# [48500/500000] samples suggested.
# [49000/500000] samples suggested.
# [49500/500000] samples suggested.
# [50000/500000] samples suggested.
# [50500/500000] samples suggested.
# [51000/500000] samples suggested.
# [51500/500000] samples suggested.
# [52000/500000] samples suggested.
# [52500/500000] samples suggested.
# [53000/500000] samples suggested.
# [53500/500000] samples suggested.
# [54000/500000] samples suggested.
# [54500/500000] samples suggested.
# [55000/500000] samples suggested.
# No counterexample found for 10000 rounds. Wrapping up algorithm.
# Found consistent automaton => Print.
# Model loaded successfully
# Finished running, terminating program.
# Finished training model nr. 2. Starting prediction.
# 2023/09/11 16:07:43 WARNING mlflow.pytorch: Stored model version '1.13.1+cu117' does not match installed PyTorch version '1.12.1'
# deleted merger
# deleted merger
# Finished prediction. Move the files to the folder now.
# Done with model nr. 2
# Starting training model nr. 3. Start-symbol=16, end-symbol=17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      12 print("Starting training model nr. {}. Start-symbol={}, end-symbol={}".format(i, start_symbol, end_symbol))
#      13 command = ["./flexfringe", "--ini={}".format(ini_path), "--start_symbol={}".format(start_symbol), \
#      14            "--end_symbol={}".format(end_symbol), "--aptafile={}".format(model_path), tmp_script_path]
# ---> 15 p = subprocess.run(command, stdout=subprocess.PIPE,
#      16                             stderr=subprocess.PIPE, universal_newlines=True)
#      17 for outstr in p.stdout:
#      18     sys.stdout.write(outstr)
#
# File ~/anaconda3/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/anaconda3/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~/anaconda3/lib/python3.10/subprocess.py:2005, in Popen._communicate(self, input, endtime, orig_timeout)
#    1998     self._check_timeout(endtime, orig_timeout,
#    1999                         stdout, stderr,
#    2000                         skip_check_and_raise=True)
#    2001     raise RuntimeError(  # Impossible :)
#    2002         '_check_timeout(..., skip_check_and_raise=True) '
#    2003         'failed to raise TimeoutExpired.')
# -> 2005 ready = selector.select(timeout)
#    2006 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2008 # XXX Rewrite these to use non-blocking I/O on the file
#    2009 # objects; they are no longer using C stdio!
#
# File ~/anaconda3/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate the models

# %%
def get_types(json_file):
    try:
        json_content = json.load(open(json_file, "rt"))
    except FileNotFoundError as e:
        raise RuntimeError(f"Json file not found: {e.filename}.")
    types = {key: i for i, key in enumerate(json_content["types"])}
    return types

def convert_type(x):
    return types[x.strip()]

# %%
import json
import pandas as pd

import numpy as np
from sklearn.metrics import balanced_accuracy_score, accuracy_score


summary_fh = open(os.path.join(result_dir, "results_summary.txt"), "wt")
summary_fh.write("Model nr. {}, Balanced_acc, Acc\n")
for i in range(2, 8):
    if i == 1: 
        continue
    print("Predicting model {}".format(i))
    label_file = os.path.join(path_to_test_sets, "1.{}.taysir.test.labels".format(i))
    labels = list()
    for j, label in enumerate(open(label_file, "rt")):
        if j==0:
            continue
        label = label.strip().strip("\n").strip()
        labels.append(int(label))
        
    result_file = os.path.join(result_dir, "taysir_model_{}.result".format(i))
    res_df = pd.read_csv(result_file, delimiter=";")
    
    types = get_types(os.path.join(result_dir, "taysir_model_{}.json".format(i)))
    types["0"] = 1
    res_df["types_mapped"] = res_df[" predicted trace type"].map(convert_type)
    
    bacc = balanced_accuracy_score(np.array(labels), res_df["types_mapped"])
    acc = accuracy_score(np.array(labels), res_df["types_mapped"])
    
    outstr = "{}, {}, {}\n".format(i, bacc, acc)
    summary_fh.write(outstr)
    summary_fh.flush()
summary_fh.close()
# Out:
# Predicting model 2
# Predicting model 3
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 23
#      20     labels.append(int(label))
#      22 result_file = os.path.join(result_dir, "taysir_model_{}.result".format(i))
# ---> 23 res_df = pd.read_csv(result_file, delimiter=";")
#      25 types = get_types(os.path.join(result_dir, "taysir_model_{}.json".format(i)))
#      26 types["0"] = 1
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'taysir_results/taysir_model_3.result'
