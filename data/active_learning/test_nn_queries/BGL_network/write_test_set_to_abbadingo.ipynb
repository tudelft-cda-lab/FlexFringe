# %%
# !ls
# Out:
# data					roc_network_bgl_only_last_element.png
# evaluate_distilled_model_results.ipynb	roc_network_bidirectional.png
# evaluate_predictions.ipynb		roc_network_only_last_element.png
# extract_sequences.ipynb			test_data.pk
# model.keras				train_data.pk
# predict_and_save.ipynb			train_model.ipynb
# preprocess_data.ipynb			write_test_set_to_abbadingo.ipynb
# roc_network_bgl_5_long_seqs.png		write_train_set_to_abbadingo.ipynb
# roc_network_bgl_bidirectional.png	X_pred.pk

# %%
import numpy as np

import pickle as pk

outf_path = "data/X_test.dat"
label_path = "data/y_test.txt"

data_path = "test_data.pk"
data = pk.load(open(data_path, "rb"))
data.keys()
# Out:
# dict_keys(['X', 'y', 'alphabet_size', 'event_mapping'])

# %%
X = data["X"]
alph_size = data["alphabet_size"]
mapping = data["event_mapping"]
y = data["y"]

assert(alph_size == len(mapping))

len(X), len(y), np.unique(y, return_counts=True), alph_size#, mapping
# Out:
# (588229, 588229, (array([0, 1]), array([307457, 280772])), 321)

# %%
mapping
# Out:
# {'99': 0,
#  '188': 1,
#  '106': 2,
#  '135': 3,
#  '244': 4,
#  '191': 5,
#  '107': 6,
#  '3': 7,
#  '<SOS>': 8,
#  '115': 9,
#  '216': 10,
#  '51': 11,
#  '18': 12,
#  '314': 13,
#  '33': 14,
#  '15': 15,
#  '225': 16,
#  '66': 17,
#  '264': 18,
#  '210': 19,
#  '197': 20,
#  '270': 21,
#  '267': 22,
#  '80': 23,
#  '73': 24,
#  '171': 25,
#  '305': 26,
#  '160': 27,
#  '45': 28,
#  '177': 29,
#  '130': 30,
#  '286': 31,
#  '125': 32,
#  '223': 33,
#  '122': 34,
#  '228': 35,
#  '170': 36,
#  '89': 37,
#  '261': 38,
#  '219': 39,
#  '127': 40,
#  '13': 41,
#  '169': 42,
#  '258': 43,
#  '274': 44,
#  '172': 45,
#  '57': 46,
#  '120': 47,
#  '7': 48,
#  '116': 49,
#  '37': 50,
#  '114': 51,
#  '139': 52,
#  '62': 53,
#  '9': 54,
#  '294': 55,
#  '204': 56,
#  '255': 57,
#  '220': 58,
#  '19': 59,
#  '121': 60,
#  '201': 61,
#  '126': 62,
#  '297': 63,
#  '279': 64,
#  '310': 65,
#  '311': 66,
#  '96': 67,
#  '158': 68,
#  '82': 69,
#  '110': 70,
#  '238': 71,
#  '302': 72,
#  '176': 73,
#  '68': 74,
#  '304': 75,
#  '318': 76,
#  '233': 77,
#  '298': 78,
#  '189': 79,
#  '198': 80,
#  '307': 81,
#  '245': 82,
#  '134': 83,
#  '278': 84,
#  '14': 85,
#  '144': 86,
#  '208': 87,
#  '143': 88,
#  '235': 89,
#  '273': 90,
#  '222': 91,
#  '11': 92,
#  '64': 93,
#  '38': 94,
#  '28': 95,
#  '109': 96,
#  '175': 97,
#  '111': 98,
#  '100': 99,
#  '214': 100,
#  '118': 101,
#  '196': 102,
#  '183': 103,
#  '242': 104,
#  '53': 105,
#  '137': 106,
#  '252': 107,
#  '163': 108,
#  '156': 109,
#  '63': 110,
#  '79': 111,
#  '299': 112,
#  '35': 113,
#  '101': 114,
#  '283': 115,
#  '315': 116,
#  '103': 117,
#  '218': 118,
#  '246': 119,
#  '276': 120,
#  '102': 121,
#  '300': 122,
#  '84': 123,
#  '265': 124,
#  '25': 125,
#  '259': 126,
#  '67': 127,
#  '266': 128,
#  '74': 129,
#  '239': 130,
#  '285': 131,
#  '87': 132,
#  '319': 133,
#  '77': 134,
#  '133': 135,
#  '200': 136,
#  '32': 137,
#  '292': 138,
#  '55': 139,
#  '152': 140,
#  '256': 141,
#  '290': 142,
#  '316': 143,
#  '248': 144,
#  '31': 145,
#  '22': 146,
#  '78': 147,
#  '251': 148,
#  '93': 149,
#  '16': 150,
#  '272': 151,
#  '275': 152,
#  '94': 153,
#  '132': 154,
#  '29': 155,
#  '195': 156,
#  '291': 157,
#  '247': 158,
#  '257': 159,
#  '138': 160,
#  '43': 161,
#  '108': 162,
#  '211': 163,
#  '95': 164,
#  '131': 165,
#  '166': 166,
#  '75': 167,
#  '234': 168,
#  '289': 169,
#  '293': 170,
#  '12': 171,
#  '306': 172,
#  '97': 173,
#  '48': 174,
#  '206': 175,
#  '277': 176,
#  '128': 177,
#  '194': 178,
#  '237': 179,
#  '229': 180,
#  '39': 181,
#  '295': 182,
#  '253': 183,
#  '4': 184,
#  '150': 185,
#  '142': 186,
#  '140': 187,
#  '227': 188,
#  '49': 189,
#  '162': 190,
#  '178': 191,
#  '217': 192,
#  '104': 193,
#  '6': 194,
#  '281': 195,
#  '230': 196,
#  '243': 197,
#  '85': 198,
#  '129': 199,
#  '8': 200,
#  '213': 201,
#  '174': 202,
#  '54': 203,
#  '296': 204,
#  '240': 205,
#  '41': 206,
#  '288': 207,
#  '34': 208,
#  '231': 209,
#  '10': 210,
#  '86': 211,
#  '212': 212,
#  '187': 213,
#  '155': 214,
#  '0': 215,
#  '280': 216,
#  '50': 217,
#  '190': 218,
#  '207': 219,
#  '226': 220,
#  '58': 221,
#  '173': 222,
#  '20': 223,
#  '83': 224,
#  '141': 225,
#  '42': 226,
#  '52': 227,
#  '164': 228,
#  '69': 229,
#  '72': 230,
#  '136': 231,
#  '60': 232,
#  '146': 233,
#  '203': 234,
#  '313': 235,
#  '56': 236,
#  '17': 237,
#  '153': 238,
#  '179': 239,
#  '271': 240,
#  '149': 241,
#  '70': 242,
#  '<EOS>': 243,
#  '154': 244,
#  '119': 245,
#  '148': 246,
#  '236': 247,
#  '199': 248,
#  '24': 249,
#  '40': 250,
#  '47': 251,
#  '5': 252,
#  '185': 253,
#  '221': 254,
#  '30': 255,
#  '184': 256,
#  '205': 257,
#  '36': 258,
#  '262': 259,
#  '1': 260,
#  '165': 261,
#  '312': 262,
#  '250': 263,
#  '168': 264,
#  '260': 265,
#  '105': 266,
#  '59': 267,
#  '182': 268,
#  '2': 269,
#  '301': 270,
#  '147': 271,
#  '309': 272,
#  '81': 273,
#  '117': 274,
#  '186': 275,
#  '308': 276,
#  '317': 277,
#  '123': 278,
#  '269': 279,
#  '303': 280,
#  '254': 281,
#  '46': 282,
#  '157': 283,
#  '282': 284,
#  '61': 285,
#  '241': 286,
#  '232': 287,
#  '268': 288,
#  '167': 289,
#  '23': 290,
#  '88': 291,
#  '124': 292,
#  '27': 293,
#  '284': 294,
#  '249': 295,
#  '71': 296,
#  '151': 297,
#  '181': 298,
#  '145': 299,
#  '224': 300,
#  '192': 301,
#  '159': 302,
#  '92': 303,
#  '113': 304,
#  '161': 305,
#  '263': 306,
#  '76': 307,
#  '26': 308,
#  '209': 309,
#  '215': 310,
#  '202': 311,
#  '65': 312,
#  '44': 313,
#  '98': 314,
#  '180': 315,
#  '112': 316,
#  '91': 317,
#  '21': 318,
#  '90': 319,
#  '193': 320}

# %%
with open(outf_path, "wt") as outf, open(label_path, "wt") as labelf:
    outf.write("{} {}\n".format(len(X), alph_size))
    for seq, label in zip(X, y):
        mapped_string = [str(x) for x in seq if x is not mapping["<SOS>"] and x is not mapping["<EOS>"]]
        outf.write("{} {} {}\n".format(label, len(mapped_string), " ".join(mapped_string)))
        labelf.write("{}\n".format(label))
